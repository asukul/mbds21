# %% [markdown]
# <a href="https://colab.research.google.com/github/asukul/mbds21/blob/main/MBDS21_Task2_LemonadeSale_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# There are multiple ways to get the dataset.

#1
#download the ipynb file from Cnavas, or download the dataset from https://www.kaggle.com/adisak/lemonade-stand
#then and import your csv file to local jupyter notebook.

#df = pd.read_csv('Lemonade2016-2.csv')

#2
#get the dataset directly from Adisak's github https://github.com/asukul/DS201
#to view the file: https://github.com/asukul/DS201/blob/master/datasets/Lemonade2016-2.csv
#to get the raw link to csv file: https://raw.githubusercontent.com/asukul/DS201/master/datasets/Lemonade2016-2.csv

data_url = "https://raw.githubusercontent.com/asukul/DS201/master/datasets/Lemonade2016-2.csv"
df = pd.read_csv(data_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
# Date           31 non-null object
# Location       32 non-null object
# Lemon          32 non-null int64
# Orange         32 non-null int64
# Temperature    32 non-null int64
# Leaflets       31 non-null float64
# Price          32 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#             Lemon      Orange  Temperature    Leaflets      Price
# count   32.000000   32.000000    32.000000   31.000000  32.000000
# mean   116.156250   80.000000    78.968750  108.548387   0.354687
# std     25.823357   21.863211     4.067847   20.117718   0.113137
# min     71.000000   42.000000    70.000000   68.000000   0.250000
# 25%     98.000000   66.750000    77.000000   90.000000   0.250000
# 50%    113.500000   76.500000    80.500000  108.000000   0.350000
# 75%    131.750000   95.000000    82.000000  124.000000   0.500000
# max    176.000000  129.000000    84.000000  158.000000   0.500000

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8         NaN    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
df.iloc[8,0]
# Out:
# nan

# %%
df.loc[8,"Date"]
# Out:
# nan

# %%
df.iloc[8,0] = '7/8/2016'
#df.loc[8,'Date']

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
#a manual way
df.loc[20,'Leaflets']
# Out:
# nan

# %%
#or you can identify the NaN by this way
df['Leaflets'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# Name: Leaflets, dtype: bool

# %%
df['Leaflets'].fillna(9999.99)
# Out:
# 0       90.00
# 1       90.00
# 2      104.00
# 3       98.00
# 4      135.00
# 5       90.00
# 6       90.00
# 7      135.00
# 8      113.00
# 9      126.00
# 10     131.00
# 11     135.00
# 12      99.00
# 13      99.00
# 14     113.00
# 15     108.00
# 16      90.00
# 17     126.00
# 18     122.00
# 19     113.00
# 20    9999.99
# 21      90.00
# 22     108.00
# 23     117.00
# 24     117.00
# 25     135.00
# 26     158.00
# 27      99.00
# 28      90.00
# 29      95.00
# 30      81.00
# 31      68.00
# Name: Leaflets, dtype: float64

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
df.drop_duplicates()
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# 13  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/7/2016    Beach    143     101           81     135.0   0.25
# 7    7/8/2016    Beach    123      86           82     113.0   0.25
# 8    7/9/2016    Beach    134      95           80     126.0   0.25
# 9   7/10/2016    Beach    140      98           82     131.0   0.25
# 10  7/11/2016    Beach    162     120           83     135.0   0.25
# 11  7/12/2016    Beach    130      95           84      99.0   0.25
# 12  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df['Leaflets'].mean()
# Out:
# 109.16666666666667

# %%
#round it
type(df['Leaflets'].mean())

round(df['Leaflets'].mean(),0)

#num1 = round(df['Leaflets'].mean(),2)
# Out:
# 109.0

# %%
#df['Leaflets'] = df['Leaflets'].fillna(num1)

df['Leaflets'] = df['Leaflets'].fillna(round(df['Leaflets'].mean(),0))

#both of these work!!

# %%
#df.loc[19,'Leaflets'] = 109

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/7/2016    Beach    143     101           81     135.0   0.25
# 7    7/8/2016    Beach    123      86           82     113.0   0.25
# 8    7/9/2016    Beach    134      95           80     126.0   0.25
# 9   7/10/2016    Beach    140      98           82     131.0   0.25
# 10  7/11/2016    Beach    162     120           83     135.0   0.25
# 11  7/12/2016    Beach    130      95           84      99.0   0.25
# 12  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df['Sales'] = df['Lemon']+df['Orange']

# %%
df['Revenue'] = df['Sales']*df['Price']

# %%
df
# Out:
#          Date Location  Lemon  Orange  ...  Leaflets  Price  Sales  Revenue
# 0    7/1/2016     Park     97      67  ...      90.0   0.25    164    41.00
# 1    7/2/2016     Park     98      67  ...      90.0   0.25    165    41.25
# 2    7/3/2016     Park    110      77  ...     104.0   0.25    187    46.75
# 3    7/4/2016    Beach    134      99  ...      98.0   0.25    233    58.25
# 4    7/5/2016    Beach    159     118  ...     135.0   0.25    277    69.25
# 5    7/6/2016    Beach    103      69  ...      90.0   0.25    172    43.00
# 6    7/7/2016    Beach    143     101  ...     135.0   0.25    244    61.00
# 7    7/8/2016    Beach    123      86  ...     113.0   0.25    209    52.25
# 8    7/9/2016    Beach    134      95  ...     126.0   0.25    229    57.25
# 9   7/10/2016    Beach    140      98  ...     131.0   0.25    238    59.50
# 10  7/11/2016    Beach    162     120  ...     135.0   0.25    282    70.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 9 columns):
# Date           31 non-null object
# Location       31 non-null object
# Lemon          31 non-null int64
# Orange         31 non-null int64
# Temperature    31 non-null int64
# Leaflets       31 non-null float64
# Price          31 non-null float64
# Sales          31 non-null int64
# Revenue        31 non-null float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ KB

# %%
df.ix['Location':'Price']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Date, Location, Lemon, Orange, Temperature, Leaflets, Price, Sales, Revenue]
# Index: []

# %%
df.loc[:,['Location','Price']]
#df.loc[:,'Location':'Price']
# Out:
#    Location  Price
# 0      Park   0.25
# 1      Park   0.25
# 2      Park   0.25
# 3     Beach   0.25
# 4     Beach   0.25
# 5     Beach   0.25
# 6     Beach   0.25
# 7     Beach   0.25
# 8     Beach   0.25
# 9     Beach   0.25
# 10    Beach   0.25
# 11    Beach   0.25
# 12    Beach   0.25
# 13    Beach   0.25
# 14    Beach   0.50
# 15    Beach   0.50
# 16    Beach   0.50
# 17     Park   0.50
# 18     Park   0.50
# 19     Park   0.50
# 20     Park   0.50
# 21     Park   0.50
# 22     Park   0.50
# 23     Park   0.50
# 24     Park   0.50
# 25     Park   0.35
# 26     Park   0.35
# 27     Park   0.35
# 28     Park   0.35
# 29    Beach   0.35
# 30    Beach   0.35

# %%
#if I want only Park location
df.loc[df['Location']=='Park',:]
# Out:
#          Date Location  Lemon  Orange  ...  Leaflets  Price  Sales  Revenue
# 0    7/1/2016     Park     97      67  ...      90.0   0.25    164    41.00
# 1    7/2/2016     Park     98      67  ...      90.0   0.25    165    41.25
# 2    7/3/2016     Park    110      77  ...     104.0   0.25    187    46.75
# 17  7/18/2016     Park    131      92  ...     122.0   0.50    223   111.50
# 18  7/19/2016     Park    122      85  ...     113.0   0.50    207   103.50
# 19  7/20/2016     Park     71      42  ...     109.0   0.50    113    56.50
# 20  7/21/2016     Park     83      50  ...      90.0   0.50    133    66.50
# 21  7/22/2016     Park    112      75  ...     108.0   0.50    187    93.50
# 22  7/23/2016     Park    120      82  ...     117.0   0.50    202   101.00
# 23  7/24/2016     Park    121      82  ...     117.0   0.50    203   101.50
# 24  7/25/2016     Park    156     113  ...     135.0   0.50    269   134.50
# ...

# %%
df
# Out:
#          Date Location  Lemon  Orange  ...  Leaflets  Price  Sales  Revenue
# 0    7/1/2016     Park     97      67  ...      90.0   0.25    164    41.00
# 1    7/2/2016     Park     98      67  ...      90.0   0.25    165    41.25
# 2    7/3/2016     Park    110      77  ...     104.0   0.25    187    46.75
# 3    7/4/2016    Beach    134      99  ...      98.0   0.25    233    58.25
# 4    7/5/2016    Beach    159     118  ...     135.0   0.25    277    69.25
# 5    7/6/2016    Beach    103      69  ...      90.0   0.25    172    43.00
# 6    7/7/2016    Beach    143     101  ...     135.0   0.25    244    61.00
# 7    7/8/2016    Beach    123      86  ...     113.0   0.25    209    52.25
# 8    7/9/2016    Beach    134      95  ...     126.0   0.25    229    57.25
# 9   7/10/2016    Beach    140      98  ...     131.0   0.25    238    59.50
# 10  7/11/2016    Beach    162     120  ...     135.0   0.25    282    70.50
# ...

# %%
df75 = df.loc[df['Temperature']>=75,:]

# %%
df75
# Out:
#          Date Location  Lemon  Orange  ...  Leaflets  Price  Sales  Revenue
# 3    7/4/2016    Beach    134      99  ...      98.0   0.25    233    58.25
# 4    7/5/2016    Beach    159     118  ...     135.0   0.25    277    69.25
# 5    7/6/2016    Beach    103      69  ...      90.0   0.25    172    43.00
# 6    7/7/2016    Beach    143     101  ...     135.0   0.25    244    61.00
# 7    7/8/2016    Beach    123      86  ...     113.0   0.25    209    52.25
# 8    7/9/2016    Beach    134      95  ...     126.0   0.25    229    57.25
# 9   7/10/2016    Beach    140      98  ...     131.0   0.25    238    59.50
# 10  7/11/2016    Beach    162     120  ...     135.0   0.25    282    70.50
# 11  7/12/2016    Beach    130      95  ...      99.0   0.25    225    56.25
# 12  7/13/2016    Beach    109      75  ...      99.0   0.25    184    46.00
# 13  7/14/2016    Beach    122      85  ...     113.0   0.25    207    51.75
# ...

# %%
df.plot.scatter(x='Leaflets',y='Sales')

# %%
plt.hist(df['Revenue'], bins = 10)
plt.title('DS201 HW2 - Revenue Histograms of Lemonade Sales')
plt.show()

# %%
df['Revenue'].plot.hist(bins=10)

# %%
df.plot.box()

# more info at https://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization-box

# %%
#pandas way, more info https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.boxplot.html
df.boxplot(by='Location', column='Sales')

# %%
df75.boxplot(by='Location', column='Sales')

# %% [markdown]
# Let's try Seaborn
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x="Location", y="Sales", data=df)

# %%
ax = sns.boxplot(x="Location", y="Sales", hue="Location",
...                  data=df, palette="Set3")

# %% [markdown]
# Seaborn pairplot
# http://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(df)

# %%
#sns.set_style="ticks"

# %%
sns.pairplot(df, kind="reg")

# %%
#sns.pairplot(df, hue="Revenue")

# %%
#sns.pairplot(df, hue="Temperature")

# %%
df.head()

# %%
max(df["Revenue"])

# %%
#How to display only the row that has a max revene

# %%
df.loc[df['Revenue']>=max(df["Revenue"]),:]
